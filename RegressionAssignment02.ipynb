# %% [markdown]
# <a href="https://colab.research.google.com/github/abakm/AL-ML_Assignment-1/blob/master/RegressionAssignment02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


# Read CSV
df = pd.read_csv("./insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# #Data Exploration

# %%
# Basic Information
print(f"Number of records: {df.shape[0]}")
print(f"Number of features: {df.shape[1]}")
print(f"nFeature Details:", df.info())
# Out:
# Number of records: 1338
# Number of features: 7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
# nFeature Details: None

# %%
# statistica Summary
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# #### Univariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 10))
sns.histplot(x=df["age"], color="red")
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x=df["bmi"], palette='pastel')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.title('BMI Distribution')
plt.show()
# Out:
# <ipython-input-56-b0fa8ba22294>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["bmi"], palette='pastel')

# %% [markdown]
# #### Categorical Analysis

# %%
plt.figure(figsize=(10, 10))
sns.countplot(x=df["sex"], palette='pastel')
plt.xlabel('sex')
plt.ylabel('Frequency')
plt.title('sex Distribution')
plt.show()
# Out:
# <ipython-input-57-12fca0722298>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["sex"], palette='pastel')

# %%
plt.figure(figsize=(10, 10))
sns.countplot(x=df["children"], palette='pastel')
plt.xlabel('Children')
plt.ylabel('Frequency')
plt.title('Children Distribution')
plt.show()
# Out:
# <ipython-input-63-b2d14b1f2d99>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["children"], palette='pastel')

# %%
plt.figure(figsize=(10, 10))
sns.countplot(x=df["smoker"], palette='pastel')
plt.xlabel('Smoker')
plt.ylabel('Frequency')
plt.title('Smoker Distribution')
plt.show()
# Out:
# <ipython-input-61-1f6b4d43a3df>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["smoker"], palette='pastel')

# %%
plt.figure(figsize=(10, 10))
sns.countplot(x=df["region"], palette='pastel')
plt.xlabel('Region')
plt.ylabel('Frequency')
plt.title('Region Distribution')
plt.show()
# Out:
# <ipython-input-64-a0e98ed69ae5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["region"], palette='pastel')

# %% [markdown]
# ### Bivariate Analysis

# %%
import seaborn as sns
plt.figure(figsize=(5,3))
sns.scatterplot(x='age', y='charges', data=df, color='r')
plt.xlabel('Age')
plt.ylabel('charges')
plt.title('Age vs charges')
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Drop Duplicates
df.drop_duplicates(inplace=True)
df
# Out:
#            age  sex       bmi  children  smoker  region      charges
# 0     0.021739    0  0.321227         0       1       3  16884.92400
# 1     0.000000    1  0.479150         1       0       2   1725.55230
# 2     0.217391    1  0.458434         3       0       2   4449.46200
# 3     0.326087    1  0.181464         0       0       1  21984.47061
# 4     0.304348    1  0.347592         0       0       1   3866.85520
# ...        ...  ...       ...       ...     ...     ...          ...
# 1333  0.695652    1  0.403820         3       0       1  10600.54830
# 1334  0.000000    0  0.429379         0       0       0   2205.98080
# 1335  0.000000    0  0.562012         0       0       2   1629.83350
# 1336  0.065217    0  0.264730         0       0       3   2007.94500
# 1337  0.934783    0  0.352704         0       1       1  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.isnull().sum()  # checking for null values
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Apply Label Encoding to sex, smoker and region

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# Apply Label Encoding to the 'sex' column
df["sex"] = label_encoder.fit_transform(df["sex"])
df["smoker"] = label_encoder.fit_transform(df["smoker"])
df["region"] = label_encoder.fit_transform(df["region"])

df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# Create a MinMaxScaler object
scaler = MinMaxScaler()

# Apply MinMax Scaling to age and bmi
df_min_max_scaled = pd.DataFrame(scaler.fit_transform(df[["age", "bmi"]]))

# Assign column names to the scaled dataframe
df_min_max_scaled.columns = ["age_scaled", "bmi_scaled"]

# Method 1: Add the scaled columns to the original dataframe
df["age"] = df_min_max_scaled["age_scaled"]
df["bmi"] = df_min_max_scaled["bmi_scaled"]

df
# Out:
#            age  sex       bmi  children  smoker  region      charges
# 0     0.021739    0  0.321227         0       1       3  16884.92400
# 1     0.000000    1  0.479150         1       0       2   1725.55230
# 2     0.217391    1  0.458434         3       0       2   4449.46200
# 3     0.326087    1  0.181464         0       0       1  21984.47061
# 4     0.304348    1  0.347592         0       0       1   3866.85520
# ...        ...  ...       ...       ...     ...     ...          ...
# 1333  0.695652    1  0.403820         3       0       1  10600.54830
# 1334  0.000000    0  0.429379         0       0       0   2205.98080
# 1335  0.000000    0  0.562012         0       0       2   1629.83350
# 1336  0.065217    0  0.264730         0       0       3   2007.94500
# 1337  0.934783    0  0.352704         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## Model Development

# %%
x = df[["age", "sex", "bmi", "children", "smoker", "region"]]
y = df["charges"]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([ 8924.40724442,  7116.29501758, 36909.01352144,  9507.87469118,
#        27013.3500079 , 10790.77956153,   226.29844571, 16942.71599941,
#         1056.63079407, 11267.91997309, 28048.59793155,  9424.36324087,
#         5326.32232088, 38460.06017922, 40303.40597026, 37147.01010262,
#        15287.91876684, 35965.05485917,  9179.1753067 , 31510.8319849 ,
#         3797.79068365, 10070.82803304,  2312.57551348,  7074.41348194,
#        11352.37224357, 12907.77079523, 14448.84678727,  6205.65997921,
#         9917.00839638,  2239.50032819,  9060.55469043, 13120.56214535,
#         4617.70702822,  3467.91218926,  4402.74821855, 12967.91608907,
#         1927.44498944,  8757.9180081 , 33324.35180597, 32638.47697026,
#         3852.41756615,  4370.39670883, 14080.76023234, 11478.63402576,
#         8829.26135924, 12046.15119133,  5322.80515731,  3100.71182484,
#        35546.60547574,  9201.61196817, 15894.23763341,  2406.04003607,
# ...
